# %% [markdown]
# <div style="display:flex; justify-content:center; align-items:center; margin:25px 0;">
#
# ![jupyter](img/logo.png)
#
# </div>

# %% [markdown]
# <div align="center">
#
# # **Variables Cualitativas**
#
# </div>

# %% [markdown]
# <div style="display:flex; justify-content:center; align-items:center; margin:25px 0;">
#
# ![jupyter](img/python.png)
#
# </div>

# %% [markdown]
# <div align="center">
#
# ## **Nombre**: ***Adriel Bedoya***
#
# </div>

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Grado' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Master' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Master' 'Master' 'Secundaria' 'Grado'
#  'Bachillerato' 'Secundaria' 'Master' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Master'
#  'Grado' 'Master' 'Grado' 'Doctorado' 'Secundaria' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Secundaria'
#  'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Master' 'Master' 'Grado'
#  'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Doctorado' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Master' 'Secundaria' 'Bachillerato' 'Master' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Master' 'Secundaria' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Doctorado' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Doctorado' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Master' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Master' 'Secundaria' 'Bachillerato' 'Grado' 'Master'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Master'
#  'Secundaria' 'Grado' 'Grado' 'Master' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Master' 'Secundaria' 'Doctorado'
#  'Secundaria' 'Grado' 'Grado' 'Master' 'Secundaria' 'Grado' 'Secundaria'
#  'Secundaria' 'Doctorado' 'Secundaria' 'Bachillerato' 'Grado' 'Master'
#  'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Doctorado' 'Master' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Doctorado' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Master' 'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Grado'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Doctorado' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Master' 'Bachillerato'
#  'Grado' 'Grado' 'Master' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Secundaria' 'Master' 'Bachillerato' 'Secundaria' 'Doctorado'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Secundaria' 'Master' 'Secundaria' 'Secundaria' 'Grado'
#  'Doctorado' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Master' 'Bachillerato' 'Master' 'Grado' 'Bachillerato'
#  'Secundaria' 'Master' 'Master' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Master'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Doctorado' 'Master' 'Secundaria'
#  'Secundaria' 'Master' 'Master' 'Master' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Master' 'Grado' 'Grado' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado'
#  'Master' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Grado' 'Secundaria' 'Master' 'Bachillerato' 'Secundaria' 'Master'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master' 'Master'
#  'Secundaria' 'Master' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información 
import pandas as pd
#Genero el dataframe con los valores que ya estaba en el ejercicio, de la lista "nivel_estudios"
df = pd.DataFrame(nivel_estudios)

# Frecuencias
frecuencia = df.value_counts()

frecuencia.plot(
    kind = "bar", # tipo de gráfico
    title = "Nivel de Educación", #título del gráfico
    xlabel = "Nivel de Estudios", #etiqueta x
    ylabel = "Personas registradas" #etiqueta y
)
# Out:
# <Axes: title={'center': 'Nivel de Educación'}, xlabel='Nivel de Estudios', ylabel='Personas registradas'>

# %% [markdown]
# # Github
# <div style="margin-left: 330px">
#
# ![](img/github.png)
# </div>

# %% [markdown]
# ## Para entrar, de click [aquí](https://github.com/AlejandroJonnath/MachineLearning2.git)
